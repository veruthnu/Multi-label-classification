# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt
import argparse
import os
from PIL import Image


image = cv2.imread('a.png')

# plt.imshow(image)

#print(pytesseract.get_languages(config = ''))

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

filename = "{}.jpg".format(os.getpid())
cv2.imwrite(filename, gray)

custom_config = r'--oem 3 --psm 4'

pytesseract.pytesseract.tesseract_cmd = "C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

# result = pytesseract.image_to_string(test_img, lang='kor', config=custom_config)

text = pytesseract.image_to_string(Image.open(filename), lang='kor', config=custom_config)
os.remove(filename)

print(text)
# plt.imshow(image)
# Out:
# 은 00 2) 8비였습자 -> 준11됐습40
# (08 끝났었누데므.-ㅡ> 끝났는에.
# 67 > 역격기4 -ㅋ 열기겨
